# 4226     大码运动内衣女防震跑步聚拢减震健身瑜伽无钢圈品牌前扣拉链文胸   89.0    广东 中山   104人付款
# 4227   大码运动内衣女防震聚拢胖mm妹妹文胸跑步背心大胸显小200斤夏季   59.0    广东 广州   213人付款
#
#                                             comment_url
# 0                                                   NaN
# 1     //detail.tmall.com/item.htm?id=572608443038&ad...
# 2     //detail.tmall.com/item.htm?id=586829143080&ad...
# 3     //detail.tmall.com/item.htm?id=20762164858&ns=...
# 4     //detail.tmall.com/item.htm?id=586985593346&ns...
# ...                                                 ...
# 4223  //item.taobao.com/item.htm?id=45155943346&ns=1...
# 4224  //detail.tmall.com/item.htm?id=601203639372&ns...
# 4225  //item.taobao.com/item.htm?id=596530839560&ns=...
# 4226  //detail.tmall.com/item.htm?id=42948120392&ns=...
# 4227  //item.taobao.com/item.htm?id=585807107885&ns=...
#
# [4171 rows x 5 columns]

# %%
location_list = []
for location in df_tb['location']:
    location_list.append(location.split(' ')[0])
df_tb['location'] = location_list
df_tb
# Out:
#                                   title  price location    sales  \
# 0                  内衣套装女收副乳调整型防下垂性感聚拢上托  148.0       广东  1107人付款
# 1        内衣套装女夏小胸文胸聚拢收副乳少女无钢圈性感蕾丝薄款透气胸罩   19.9       广东  2114人付款
# 2        女士内衣女无钢圈聚拢小胸收副乳上托性感薄款胸罩调整型文胸套装  129.0       广东  3852人付款
# 3         遐大胸显小全罩杯超薄文胸 性感蕾丝大码胸罩无海绵薄款内衣女  125.0       安徽  3766人付款
# 4        NEIWAI内外杜鹃同款零敏罗纹三角棉质小胸内衣女无钢圈文胸  199.0       上海  1873人付款
# ...                                 ...    ...      ...      ...
# 4223  天天特价正品贵夫人文胸FA8368光面无钢圈B薄内衣胸罩夏纯色睡眠   43.0       上海   181人付款
# 4224     古炫酒红色无痕内衣女套装小胸厚聚拢无钢圈胸罩性感文胸内裤一套   59.9       广东   116人付款
# 4225     运动内衣女防震跑步聚拢减震背心式大胸显小健身薄款学生定型文胸   49.0       广东   304人付款
# 4226     大码运动内衣女防震跑步聚拢减震健身瑜伽无钢圈品牌前扣拉链文胸   89.0       广东   104人付款
# 4227   大码运动内衣女防震聚拢胖mm妹妹文胸跑步背心大胸显小200斤夏季   59.0       广东   213人付款
#
#                                             comment_url
# 0                                                   NaN
# 1     //detail.tmall.com/item.htm?id=572608443038&ad...
# 2     //detail.tmall.com/item.htm?id=586829143080&ad...
# 3     //detail.tmall.com/item.htm?id=20762164858&ns=...
# 4     //detail.tmall.com/item.htm?id=586985593346&ns...
# ...                                                 ...
# 4223  //item.taobao.com/item.htm?id=45155943346&ns=1...
# 4224  //detail.tmall.com/item.htm?id=601203639372&ns...
# 4225  //item.taobao.com/item.htm?id=596530839560&ns=...
# 4226  //detail.tmall.com/item.htm?id=42948120392&ns=...
# 4227  //item.taobao.com/item.htm?id=585807107885&ns=...
#
# [4171 rows x 5 columns]

# %%
sales_list = []
for sale in df_tb['sales']:
    sale = sale[:-3].replace('+', '')
    if '万' in sale:
        sale = int(float(sale[:-1]) * 10000)
    sales_list.append(sale)
df_tb['sales'] = sales_list

# %%
df_tb.head(10)
# Out:
#                                      title  price location sales  \
# 0                     内衣套装女收副乳调整型防下垂性感聚拢上托  148.0       广东  1107
# 1           内衣套装女夏小胸文胸聚拢收副乳少女无钢圈性感蕾丝薄款透气胸罩   19.9       广东  2114
# 2           女士内衣女无钢圈聚拢小胸收副乳上托性感薄款胸罩调整型文胸套装  129.0       广东  3852
# 3            遐大胸显小全罩杯超薄文胸 性感蕾丝大码胸罩无海绵薄款内衣女  125.0       安徽  3766
# 4           NEIWAI内外杜鹃同款零敏罗纹三角棉质小胸内衣女无钢圈文胸  199.0       上海  1873
# 5           NEIWAI内外杜鹃同款|零敏玲珑小胸棉内衣女无钢圈文胸透气  169.0       上海  1414
# 6  华歌尔Wacoal GOCOCI日本同款舒适薄款背心式无钢圈文胸 WB8637  239.0       上海   674
# 7       歌瑞尔【2件装】内衣女无钢圈小胸聚拢文胸女士内衣组合ABB18110  149.0       广东  4448
# 8           歌瑞尔旗下内衣女小胸聚拢无钢圈文胸套装【2件文胸+2条内裤】  199.0       广东  1811
# 9       歌瑞尔旗下少女舒适薄款性感光面无痕内衣女无钢圈文胸罩ABB18048   79.0       广东  7000
#
#                                          comment_url
# 0                                                NaN
# 1  //detail.tmall.com/item.htm?id=572608443038&ad...
# 2  //detail.tmall.com/item.htm?id=586829143080&ad...
# 3  //detail.tmall.com/item.htm?id=20762164858&ns=...
# 4  //detail.tmall.com/item.htm?id=586985593346&ns...
# 5  //detail.tmall.com/item.htm?id=527120339863&ns...
# 6  //detail.tmall.com/item.htm?id=549120918840&ns...
# 7  //detail.tmall.com/item.htm?id=575098674068&ns...
# 8  //detail.tmall.com/item.htm?id=533635199394&ns...
# 9  //detail.tmall.com/item.htm?id=569977349708&ns...

# %%
df_tb.to_excel('standard_goods.xlsx',index=None)

# %%
locations = [location for location in df_tb['location'].value_counts().items()]

# %%
locations
# Out:
# [('广东', 2398),
#  ('上海', 555),
#  ('浙江', 423),
#  ('福建', 238),
#  ('江苏', 184),
#  ('北京', 50),
#  ('湖北', 49),
#  ('陕西', 41),
#  ('山东', 41),
#  ('江西', 38),
#  ('安徽', 36),
#  ('辽宁', 28),
#  ('重庆', 14),
#  ('四川', 10),
#  ('河北', 10),
#  ('湖南', 9),
#  ('河南', 8),
#  ('香港', 7),
#  ('美国', 7),
#  ('吉林', 5),
#  ('天津', 5),
#  ('广西', 4),
#  ('青海', 3),
#  ('日本', 3),
#  ('泰国', 2),
#  ('山西', 1),
#  ('法国', 1),
#  ('贵州', 1)]

# %%
import jieba
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from pyecharts.globals import SymbolType
from pyecharts.charts import Pie, Bar, Map, WordCloud, Page

# %%
map = (
    Map()
        .add("店铺数量",
            [list(location) for location in locations], "china")
        .set_global_opts(
            title_opts=opts.TitleOpts(title='地址分布图'),
             visualmap_opts=opts.VisualMapOpts(max_=3000),
        )
)

# %%
#map.render_notebook()
#map.render()

# %%
# 词云
df_bra = pd.read_excel(r'C:\Users\v0cn140\Desktop\可视化\数据可视化演示\standard_excel\standard_goods_comments.xlsx')
df_bra['comment']
# Out:
# 0           每年固定双十一买五套，正好每套两个月，今年这几个颜色更差了，但质量比去年优秀，真的是裸感。
# 1       不厚无钢圈，第一回买这个牌子，款式好看，买了两件，感觉舒适度一般，懒得退了。。粉色的应该是别...
# 2       上身效果：很合适 很贴身 厚薄度：适中 尺码推荐：很准确 材质特性：描述一致 罩杯推荐：很准...
# 3       没有买过VS，自己根据尺码表算的尺寸没想到挺合适。很喜欢这件内衣很薄很透气，没有钢圈午睡也很...
# 4         终于等到双十一买了4件，维密家的内衣面料是穿过的内衣里面质感最好的，舒服度也很高，无限回购！！
#                               ...
# 3669                        鞋很好，物美价廉物流速度快，这个价位质量还这么好，非常赞?
# 3670                   昨天下单，今天就到了，京东物流???！质量很好！需要的朋友赶紧下单哦
# 3671                                非常好，质量不错，大小很合适，卖家态度很好
# 3672                               穿着很舒服！不错的选择！质量很好！真心喜欢！
# 3673                          穿着很舒服，质量也很好，活动购 价值66元算便宜了吧！
# Name: comment, Length: 3674, dtype: object

# %%
import jieba
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud

text = ' '.join(jieba.cut(str([comment for comment in df_bra['comment']])))
mask = np.array(Image.open("brassier.jpg"))
wc = WordCloud(mask=mask,font_path='C:\Windows\Fonts\SimHei.ttf',mode='RGBA').generate(text)
 
#plt.imshow(wc, interpolation='bilinear')
#plt.axis("off")
#plt.show()

wc.to_file('cloudImage.png')

# %%
[size for size in  df_bra['bra_size'].value_counts().items()]
# Out:
# [('B', 1909), ('C', 810), ('A', 696), ('D', 259)]

# %%
total_cup = sum(count[1] for count in [size for size in  df_bra['bra_size'].value_counts().items()])
total_cup
# Out:
# 3674

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.commons.utils import JsCode


fn = """
    function(params) {
        if(params.name == 'other')
            return '\\n\\n\\n' + params.name + ' : ' + params.value + '%';
        return params.name + ' : ' + params.value + '%';
    }
    """


def new_label_opts():
    return opts.LabelOpts(formatter=JsCode(fn), position="center")


pie = (
    Pie()
    .add(
        "",
        [['A_cup', round(696/total_cup, 2)*100],['other',round(1 - 696/total_cup, 2)*100]],
        center=["20%", "30%"],
        radius=[60, 80],
        label_opts=new_label_opts(),
    )
    .add(
        "",
        [['B_cup', round(1909/total_cup, 2)*100],['other',round(1 - 1909/total_cup, 2)*100]],
        center=["55%", "30%"],
        radius=[60, 80],
        label_opts=new_label_opts(),
    )
    .add(
        "",
        [['C_cup', round(810/total_cup, 2)*100],['other',round(1 - 810/total_cup, 2)*100]],
        center=["20%", "70%"],
        radius=[60, 80],
        label_opts=new_label_opts(),
    )
    .add(
        "",
        [['D_cup', round(259/total_cup * 100, 1)],['other',round(1 - 259/total_cup, 2)*100]],
        center=["55%", "70%"],
        radius=[60, 80],
        label_opts=new_label_opts(),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Cup-多饼图"),
        legend_opts=opts.LegendOpts(
            type_="scroll", pos_top="20%", pos_left="80%", orient="vertical"
        ),
    )
)
#pie.render_notebook()

# %%
#pie.render()

# %%
from pyecharts.faker import Faker
bar = (
    Bar()
    .add_xaxis(Faker.days_attrs)
    .add_yaxis("商家A", Faker.days_values)
    .reversal_axis()
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-DataZoom（slider+inside）"),
        datazoom_opts=[opts.DataZoomOpts()]
    )
    #.render("bar_datazoom_both.html")
)
#bar.render_notebook()

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

v = Faker.choose()
pie1 = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(v, list(range(10,80,10)))],
        radius=["30%", "75%"],
        center=["25%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add(
        "",
        [list(z) for z in zip(v, list(range(10,80,10))[::-1])],
        radius=["30%", "75%"],
        center=["75%", "50%"],
        rosetype="area",
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
)
#pie1.render_notebook()

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid

liquid = (
    Liquid()
    .add("lq", [0.45,0.5])	
    .set_global_opts(title_opts=opts.TitleOpts(title="今日湿度"))
)
#liquid.render_notebook()

# %%
page = Page(layout=Page.DraggablePageLayout)
page.add(
    bar,
    liquid,
    pie,
    map,
    pie1
)
#page.render_notebook()

# %%
page.render()
# Out:
# 'C:\\Users\\v0cn140\\Desktop\\可视化\\数据可视化演示\\render.html'

# %%
Page.save_resize_html('render.html',cfg_file= 'chart_config.json') # will generate resize_render.html
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n    <meta charset="UTF-8">\n    <title>Awesome-pyecharts</title>\n            <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts-liquidfill.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/maps/china.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/jquery.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/jquery-ui.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/ResizeSensor.js"></script>\n\n            <link rel="stylesheet"  href="https://assets.pyecharts.org/assets/jquery-ui.css">\n\n</head>\n<body>\n    <style>.box {  }; </style>\n        \n    <div class="box">\n                <div id="ef90f226e5374e98bb75513aab68434b" class="chart-container" style="position: absolute; width: 640px; height: 300px; top: 36px; left: 10px;"></div>\n    <script>\n        var chart_ef90f226e5374e98bb75513aab68434b = echarts.init(\n            document.getElementById(\'ef90f226e5374e98bb75513aab68434b\'), \'white\', {renderer: \'canvas\'});\n        var option_ef90f226e5374e98bb75513aab68434b = {\n    "animation": true,\n    "animationThreshold": 2000,\n    "animationDuration": 1000,\n    "animationEasing": "cubicOut",\n    "animationDelay": 0,\n    "animationDurationUpdate": 300,\n    "animationEasingUpdate": "cubicOut",\n    "animationDelayUpdate": 0,\n    "color": [\n        "#c23531",\n        "#2f4554",\n        "#61a0a8",\n        "#d48265",\n        "#749f83",\n        "#ca8622",\n        "#bda29a",\n        "#6e7074",\n        "#546570",\n        "#c4ccd3",\n        "#f05b72",\n        "#ef5b9c",\n        "#f47920",\n        "#905a3d",\n        "#fab27b",\n        "#2a5caa",\n        "#444693",\n        "#726930",\n        "#b2d235",\n        "#6d8346",\n        "#ac6767",\n        "#1d953f",\n        "#6950a1",\n        "#918597"\n    ],\n    "series": [\n        {\n            "type": "bar",\n            "name": "\\u5546\\u5bb6A",\n            "legendHoverLink": true,\n            "data": [\n                6,\n                10,\n                30,\n                24,\n                15,\n                6,\n                8,\n                15,\n                18,\n                21,\n                23,\n                17,\n                26,\n                11,\n                6,\n                14,\n                15,\n                27,\n                13,\n                16,\n                27,\n                20,\n                16,\n                1,\n                15,\n                26,\n                14,\n                16,\n                16,\n                25\n            ],\n            "showBackground": false,\n            "barMinHeight": 0,\n            "barCategoryGap": "20%",\n            "barGap": "30%",\n            "large": false,\n            "largeThreshold": 400,\n            "seriesLayoutBy": "column",\n            "datasetIndex": 0,\n            "clip": true,\n            "zlevel": 0,\n            "z": 2,\n            "label": {\n                "show": true,\n                "position": "top",\n                "margin": 8\n            }\n        }\n    ],\n    "legend": [\n        {\n            "data": [\n                "\\u5546\\u5bb6A"\n            ],\n            "selected": {\n                "\\u5546\\u5bb6A": true\n            },\n            "show": true,\n            "padding": 5,\n            "itemGap": 10,\n            "itemWidth": 25,\n            "itemHeight": 14\n        }\n    ],\n    "tooltip": {\n        "show": true,\n        "trigger": "item",\n        "triggerOn": "mousemove|click",\n        "axisPointer": {\n            "type": "line"\n        },\n        "showContent": true,\n        "alwaysShowC ...
